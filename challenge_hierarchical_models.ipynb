# %% [markdown]
# ## Hierachical Models Assignment

# %%
# import pandas
import pandas as pd
# import Agglomerative clustering
from sklearn.cluster import AgglomerativeClustering
# import scipy.cluster.hierarchy
import scipy.cluster.hierarchy as sch
# import numpy
import numpy as np
# import matplotlib
import matplotlib.pyplot as plt
# set figure size
plt.rcParams["figure.figsize"] = (12,8)

# %%
# Load dataframe
df = pd.read_csv('mall_customers.csv')

# %% [markdown]
# ## Objective:
#
# - Fit Hierarchical clustering,
# - find optimal number of clusters via dendrogram
# - and plot clusters.
#
# Again, to simplify plotting in 2-D, we can create clustering model based on the last two columns of the dataset only.

# %%
# Import necessary libraries
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# %%
# Prepare predictors
X = df.iloc[:, -2:]

# %%
# Create a linkage matrix
linked = linkage(X, 'ward')

# %% [markdown]
# * define function plot_dendogram

# %%
# Define function to plot dendrogram
def plot_dendrogram(linked):
    plt.figure(figsize=(10, 7))
    dendrogram(linked,
               orientation='top',
               distance_sort='descending',
               show_leaf_counts=True)
    plt.show()

# %% [markdown]
# * Plot dendrogram

# %%
# Call the function to plot dendrogram
plot_dendrogram(linked)

# %% [markdown]
# * Fit Hierarchical clustering with optimal number of clusters

# %%
# Fit AgglomerativeClustering with the optimal number of clusters
# Here, I'm assuming the optimal number of clusters is 2 based on the dendrogram
ac = AgglomerativeClustering(n_clusters=2)
ac.fit(X)
# Out:
# AgglomerativeClustering()

# %% [markdown]
# * define function plot_clusters

# %%
# Define function to plot clusters
def plot_clusters(df, model):
    plt.figure(figsize=(6,6))
    plt.scatter(df.iloc[:, -3], df.iloc[:, -2], c=model.labels_)
    plt.show()

# %% [markdown]
# * Plot HC clusters

# %%
# Call the function to plot clusters
plot_clusters(df, ac)
